# %% [markdown]
# # HANDWRITTEN DIGITS PREDICTION USING VOTING CLASSIFICATION
# _Builds an ensemble by implementing a voting classifier over multiple classifiers to experiment if it can outperform each individual classifier in classifying handwritten digits from MNIST dataset._

# %%
# Imports required modules, classes and methods

import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Retrieving the Data

# %%
# Loads the fashion mnist dataset

with open("./datasets/mnist_784.pickle", "rb") as f:
    X_mnist, y_mnist = pickle.load(f)

# %%
# Checks the shape of the datazz
X_mnist.shape

# %% [markdown]
# ## Data Preparation

# %%
# Checks the label of the dataset
print(y_mnist)

# %%
# Converts type of the targets into integer
y_mnist = y_mnist.astype("int")

# %%
# Splits the dataset into train and test set

X_train, X_test, y_train, y_test = train_test_split(
    
    # CODE HERE to set full feature values with targets seperated by comma
    
    test_size=10_000,   # Number of instances to seperate for testing
    random_state=42,    # For reproducibility for operations that rely on randomness
    
    stratify= # CODE HERE to set target to ensure (near) equal class distribution across splits
    )

# %%
# Further, seperates validation set from the train set

X_train, X_val, y_train, y_val = train_test_split(
    # CODE HERE to set feature values and targets extracted for training
    
    test_size=10_000, 
    random_state=42, 
    
    stratify= # CODE HERE to set training target to ensure (near) equal class distribution across splits
    )

# %%
# prints the shape of all the datasets

print("Train set shape:", X_train.shape)
print("Validation set shape:", X_val.shape)
print("Test set shape:", X_test.shape)

# %%
# Checks the maximum value in the data to consider for scaling
X_mnist.max()

# %%
# Normalizes input applying standardization


std_scaler = # CODE HERE  to initialize standard scaler class StandardScaler with default parameters

# fit it with train set and then transform train, validation and test set.
X_train = # CODE HERE
X_val = # CODE HERE
X_test = # CODE HERE

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Hard Voting

# %%
estimators = [
    ("svc_clf", # CODE HERE to initialize class LinearSVC with parameter `tol` with value 0.001 and random_state as 42),
    ("rf_clf", # CODE HERE to initialize class RandomForestClassifier with parameter random_state as 42),
    ("ex-tree_clf", # CODE HERE to initialize class ExtraTreesClassifier with parameter random_state as 42),
    ("mlp_clf", # CODE HERE to initialize class MLPClassifier with parameter random_state as 42)
    ]

# %%
voting_clf =    # CODE HERE to initialize voting classifier class VotingClassifier with parameters 
                # `estimators` with estimators list created above, 
                # `voting` as "hard", 
                # `n_jobs` as -1,
                # `verbose` as True

# %%
# CODE HERE to call .fit() method on initialized classifier voting_clf
# passing it feature values and targets for training set as parameters
# for voting classifier to fit all the containing estimators.


# NOTE: The following step may take several minutes to complete

# %% [markdown]
# **Performance Analysis of <u>Hard</u> Voting Classifier**

# %% [markdown]
# Performance Analysis on Validation Set:

# %%
print("Validation Score of individual estimator in the voting classifier:")

for estimator in voting_clf.estimators_:
    print("\t{}: {}".format(estimator, estimator.score(X_val, y_val)))

# %%
# CODE HERE to evaluate voting classifier's classification performance
# on validation data by calling .score method on classifier voting_clf and
# passing feature values and targets for validation set.

# %% [markdown]
# Performance Analysis on Test Set:

# %%
print("Test Score of individual estimator in the voting classifier:")

for estimator in voting_clf.estimators_:
    print("\t{}: {}".format(estimator, estimator.score(X_test, y_test)))

# %%
# CODE HERE to evaluate voting classifier's classification performance
# on test data by calling .score method on classifier voting_clf and
# passing feature values and targets for test set.

# %% [markdown]
# **Observations:**
#
# 1) Notice the shape of the full dataset.
#
# 2) What should be the selection criteria for models should be if ensemble would be based on voting scheme?
#
# 3) Check individual estimator performance and compare that of the voting classifier.
#
# 2) Analyze the voting classifier's prediction performance on validation and test set.
