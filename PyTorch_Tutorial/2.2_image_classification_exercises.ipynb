# %% [markdown]
# # Exercises on Image Classification: Recognision Handwritten Character
#
# In this exercise you will build a neural network model to recognize letters from the EMNIST Letters dataset. You should be writing code in the placeholder cells below. As the overall approach will remain the same as explained in the respective tutorial notebook, you may refer to that for assistance.

# %% [markdown]
# ## Importing Packages

# %%
# <Code to import packages>
# ...
import torch
import torch.nn as nn
import torchvision

# %% [markdown]
# ## Data Ingestion & Preprocessing

# %%
# <Perform data transformation preferably using `torchvision.transforms.v2` instead of `torchvision.transforms'
# ...

# %%
# Load the EMNIST datasets
# ...

# %%
# Create data loaders for both train and test set
# ...

# %% [markdown]
# ## Modeling

# %%
# Define a neural network for modeling class either by inheriting it from
# `nn.Module` or by creating instance of class `nn.Sequential`.
# ...

# %% [markdown]
# ## Model Training

# %%
# Check for GPU and set the device accordingly
# ...

# %%
# Initialize the model and move to device
# ...

# Set loss function
# ...

# Set optimizer
# ...

# %%
def train_epoch(model, train_loader, loss_function, optimizer, device):
    """
    Trains a model using data loader over one epoch
    """
    
    # Set the mode into training
    # ...

    # Initializes internal variables
    # ...

    # Enumerate over data loader to train model in batches
    for batch_idx, (data, targets) in enumerate(train_loader):
        
        # Move both data and targets to the device
        # ...

        # Resets gradients before processing next batch
        # ...

        # Forward passes the transformed data through model and gets the outputs
        # ...

        # Compute the cross entropy loss between outputs and target.
        # ...

        # Perform backpropagation
        # ...

        # Perform one step of optimization on the model parameters
        # ...

        # Track improvement by aggregating losses over certain batches
        # ...
        # Shows progress with improvement
        # ...

# %% [markdown]
# **Training Loop**

# %%
num_epochs = # Set count for certain number epochs

# Iterate over each epoch and call method `train_epoch` passing all required parameters.
# ...

# %% [markdown]
# ## Model Evaluation

# %%
def evaluate(model, test_loader, device):
    """
    Evaluate a trained model's prediction nperformance against a data loader and device
    """

    # Set model's gradient mode

    # With gradient tracking disabled:
        # iterate/enumerate over test set loader, check the prediction performance
        # and show on-screen.

# %%
# Calculates the model's accuracy on the test dataset by calling method `evaluate` with required parameters
# ...
